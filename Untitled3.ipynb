# %%
print("hello world")
# Out:
# hello world

# %%
print(10-5+2)
# Out:
# 7

# %% [markdown]
# Variables in Python

# %%
print(20+30)
print(30-20)
print(30*20)
print(30/20)
# Out:
# 50
# 10
# 600
# 1.5

# %%
a = 10 #variable/placeholder
b = 2

print(a+b)
print(b-a)
print(a*b)
print(b/a)
# Out:
# 12
# -8
# 20
# 0.2

# %%
name = "Shariful"
print(name)
# Out:
# Shariful

# %% [markdown]
# Dynamically datatype defined in python

# %%
print ("my","age is", 23.5)
# Out:
# my age is 23.5

# %% [markdown]
# Datatypes

# %%
name = "Shariful Islam" # text - string -> str
roll = 10 # number -> Interger -> int
pi = 3.1416 # number -> FLoating point number -> float
is_raining = False # boolean -> bool (True/ False)-- cant be written starting with f or t

# %%
type(is_raining)
# Out:
# bool

# %%
type("3.14")
#type(3.14)
# Out:
# str

# %%
type(False) #type("False")
# Out:
# bool

# %% [markdown]
# Comparison Operator

# %%
print(10 > 6)
print(10 < 6)
print(10 == 6)
print(10 != 6)
print(10 <= 6)
print(10 >= 6)
# Out:
# True
# False
# False
# True
# False
# True

# %%
#comment

"""
multiline comment
shariful
"""

print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # type conversion('int()')
# - 1
# -2

# %%
digit = (10)

# %%
print(type(digit))
# Out:
# <class 'int'>

# %%
str(roll)
# Out:
# '10'

# %%
roll = 10
float(roll)
# Out:
# 10.0

# %%
type(str(True))
# Out:
# str

# %% [markdown]
# Arithmetic Operator

# %%
print(10/3) #division
print(10//3) # floor division
print(10%4)#modulus operator
# Out:
# 3.3333333333333335
# 3
# 2

# %%
print(4**2) #power operator
# Out:
# 16

# %%
##login / register / taking input using keyboard

user = input("Enter your username: ")
print("so yourname is ", user)
# Out:
# Enter your username: shariful
# so yourname is  shariful

# %%
num = input("Enter a number: ") #user input always a string
print(type(num))
# Out:
# Enter a number: 10
# <class 'str'>

# %%
type(num)
# Out:
# str

# %%
num = int(num)
print(type(num))
# Out:
# <class 'int'>

# %%
num = int(input("Enter a number: ")) #user input always a string
print(type(num))
# Out:
# Enter a number: a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2962/3777948822.py in <cell line: 0>()
# ----> 1 num = int(input("Enter a number: ")) #user input always a string
#       2 print(type(num))
#
# ValueError: invalid literal for int() with base 10: 'a'

# %% [markdown]
# explicitly type cast sometimes

# %% [markdown]
# ...........

# %% [markdown]
# String Concatenation and Repeatation

# %%
print("Title: Im shariful")
print("-"*30)
# Out:
# Title: Im shariful
# ------------------------------

# %%
"Hello"*30
# Out:
# 'HelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHelloHello'

# %%
"Hello" + "0" + " " + "Hello"
# Out:
# 'Hello0 Hello'

# %% [markdown]
# operator overloading

# %%
name = "Shariful"
print("Hello world" + name)
print("Hello world", name)
# Out:
# Hello worldShariful
# Hello world Shariful

# %% [markdown]
# #Output formatting using print()

# %%
day = "10"
month = "07"
year = "2026"

print(day,month,year)
print(day,month,year, sep="-")
print(day+month+year)
# Out:
# 10 07 2026
# 10-07-2026
# 10072026

# %%
#f - string

name = "Shariful"
Roll = 10

print(name, roll)
# Out:
# Shariful 10

# %%
print("Name:", name, "Roll:", roll)
# Out:
# Name: Shariful Roll: 10

# %%
print(f"Name:      {name}, Roll - > {roll}")
# Out:
#   File "/tmp/ipykernel_2962/1502183835.py", line 1
#     print(f"Name:      {name}, "Roll - > {roll})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(f"Name:\t{name}\nRoll:\t{roll}")
# Out:
# Name:	Shariful
# Roll:	10

# %%
dollar_coversion_rate = 126.372
print(f"Dollar conversion rate: {dollar_coversion_rate: .3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2962/2370916042.py in <cell line: 0>()
#       1 dollar_coversion_rate = 126.372
# ----> 2 print(f"Dollar conversion rate: {dollar_converison_rate: .3f}")
#
# NameError: name 'dollar_converison_rate' is not defined

# %% [markdown]
# #Basics of Debugging

# %%
print("Hello World)
# Out:
#   File "/tmp/ipykernel_2962/2771583741.py", line 1
#     print("Hello World)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2962/1189138062.py in <cell line: 0>()
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# #Task

# %%
## make a simple calculator
#user input ,num1,num 2
#num1, num2,+ -
print(f)
